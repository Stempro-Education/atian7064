# %%
import pprint
import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urlparse
from bs4.element import Comment
import urllib.request
import sys
import os
from os import path
from datetime import datetime
import csv
class CollegeCrawl(object):
    gap_Insecond=5
    max_Pages=150
    allUrls={}
    visitedUrls=set()
    rejectedUrls=set()
    n_allUrls=0
    n_sitedUrls=0
    n_rejectedUrls=0
    
    """
        collegename: name
        rooturl: www.university.edu
        prioritykeywords: ['apply','adimission'...] etc. if None then every page 
        respectrobottxt: True
    """
    def __init__(self,_collegename, _rooturl, _prioritykeywords, _respectrobottxt=True):
        self.college=_collegename
        self.rootUrl=_rooturl
        self.priorityKeywords=_prioritykeywords
        self.respectRobottext=_respectrobottxt

    """
        get all urls starting from rootUrl
    """
    def all_pages(self, base_url, links_only=True):
        response=requests.get(base_url)
        allUrls={base_url}
        visitedUrls=set()
        rejectedUrls=set()
        while len(allUrls)>len(visitedUrls):
            soup=BeautifulSoup(response.text, 'html.parser')
            for link in soup.find_all('a'):
                try:
                    url=link['href']                
                    parsed_uri = urlparse(url )
                    if parsed_uri.netloc=='':
                        absolute_url=base_url+url    
                    elif parsed_uri.netloc==base_domain:
                        absolute_url=url
                    else:
                        continue
                    clean=re.sub(r'[_+!@#$?\\\s]+$', '', absolute_url).replace('.edu','.edu/').replace('.edu//','.edu/')
                    allUrls.add(clean)               
                except:
                    continue
            unvisited_url=(allUrls-visitedUrls-rejectedUrls).pop()
            visitedUrls.add(unvisited_url)
            response=requests.get(unvisited_url)
            if response.status_code!=200:
                rejectedUrls.add(unvisited_url)  
        return [allUrls[0:max_Pages],visitedUrls,rejectedUrls] if len(allUrls)>150 else [allUrls,visitedUrls,rejectedUrls]
    
    """
        read one page
    """
    def Read_OneUrl(self):
        resonse = requests.get(unvisited_url) 
        soup = BeautifulSoup(resonse.content, "html.parser")
        in_the_page=set([tag.name for tag in soup.find_all()]) 
 
        go_throug=in_the_page.intersection(need_tag_list) 
   
        for tag in go_throug:   
            sub_soups=soup.find_all(tag) 
            for one_by_one in sub_soups: 
                data1=one_by_one.findAll(text=True)
                r1=filter(visible, data1)
                textcontent=[i for i in r1 if len(i)>2]   
                print(textcontent)
    """            
        Save One Page
    """
    def Save_OnePage(self, url,folder=None,filename=None,format='csv'):
        url=url.strip()
        print(url)

# %%
names=['MIT','Yale','University of Washington','Stanford']
urls=['http://mit.edu/','http://yale.edu/','http://washington.edu/','http://stanford.edu/']
k=['apply,admission']
for q in range(4):
    c=CollegeCrawl(names[q],urls[q],k)
    a=c.all_pages(urls[q])
    for x in list(a[1]):
        c.Save_OnePage(x)
    c.Save_Summaries(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-80d56ca157aa> in <module>
#       6     a=c.all_pages(urls[q])
#       7     for x in list(a[1]):
# ----> 8         c.Save_OnePage(x)
#       9     c.Save_Summaries(a)
#
# <ipython-input-5-81bd49e48db8> in Save_OnePage(self, url, folder, filename, format)
#      86     def Save_OnePage(self, url,folder=None,filename=None,format='csv'):
#      87         url=url.strip()
# ---> 88         content=self.Read_OneUrl(url) #in format of (a,a,a,a)
#      89
#      90         if folder==None:
#
# TypeError: Read_OneUrl() takes 1 positional argument but 2 were given
