# %%
import re 
import spacy  
from spacy import displacy 
import en_core_web_sm 
from pathlib import Path 
from IPython.display import display, Markdown, Latex
import sys 
import csv 
import pandas as pd 
import numpy as np 
import os 
from os import path 
from datetime import datetime 
from urllib.parse import urlparse, urljoin 
import requests 
import ntpath 
from bs4 import BeautifulSoup, Comment 
import time 
from pprint import pprint  
import shutil 
import tldextract 
import multiprocessing 
from multiprocessing import Process, Queue, cpu_count 
import os 
from os import path, listdir
###
from IPython.core.debugger import set_trace
import random
from fractions import Fraction
import nltk
import pprint as pp
from collections import Counter
from itertools import repeat, chain
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer

# %%
nltk.download_shell()

# %%
from IPython.display import display, Markdown, Image
display(Markdown(
"""
# Midterm Project Learning Status Check
## <font color="red">Due: Feb 1, 2020</font>
## Open Book Midterm:
<ol>
    <li><b>(200 Points)Project Statement</b><br>: What are we doing? and in high level, how we are doing it <br>You may review Phase I/II PowerPoints.<br>Words limit: 500 
    <br></li>
    <br><li><b>(200 Points)Impersonate and Search</b><br>:Sign in US News Compass and conduct 3 to 5 searches. <br> Save the results to HTML files (one file per search) 
    <br><a href="https://premium.usnews.com/best-colleges/myfit?gpa=4.0&mode=table&sat-composite=1580">Compass Search</a>
    <br>A sample file from search may look like this: <br>
    <a href='./img/OneSampleCompassHtml.html'> One Sample file</a>
    </li>
    <br><li><b>(800 Points)Python and Content</b><br>Design and Implement a Class to extrat result from pages generated 
    from previous question. <br>Ideal output format should reflect at the following information:  </li>
    <br> Search Criteria: <br><img src="./img/CompassSearchFields.PNG" width="500"/>
    <br> Search Results: <br><img src="./img/CompassSearchResults.PNG" width="500"/></li>
    <br><li><b>(400 Points)Scratching NLTK</b><br>Crawl the following page<br>
    <a href="https://www.nme.com/features/greta-thunberg-full-speech-to-the-un-2019-climate-change-summit-2550824">Greta Thunberg UN Speech</a></li>
    <br> Tasks: 
    <br><ul>
        <li>Get the content of her speech</li>
        <li>Build a dataset that list all words in this speech and how many times each word appears</li>
        <li>Sort the list of words by <br>a).Alphabetically. <br> b). by frequency
        <li>Lemmatize all words</li>
        <li>Choose ~30 "difficult" words and get the synonyms and antoyms for them.</li> 
    </ul>
    </li>
</ol>
"""
))
# Out:
# # Midterm Project Learning Status Check
# ## <font color="red">Due: Feb 1, 2020</font>
# ## Open Book Midterm:
# <ol>
#     <li><b>(200 Points)Project Statement</b><br>: What are we doing? and in high level, how we are doing it <br>You may review Phase I/II PowerPoints.<br>Words limit: 500
#     <br></li>
#     <br><li><b>(200 Points)Impersonate and Search</b><br>:Sign in US News Compass and conduct 3 to 5 searches. <br> Save the results to HTML files (one file per search)
#     <br><a href="https://premium.usnews.com/best-colleges/myfit?gpa=4.0&mode=table&sat-composite=1580">Compass Search</a>
#     <br>A sample file from search may look like this: <br>
#     <a href='./img/OneSampleCompassHtml.html'> One Sample file</a>
#     </li>
#     <br><li><b>(800 Points)Python and Content</b><br>Design and Implement a Class to extrat result from pages generated
#     from previous question. <br>Ideal output format should reflect at the following information:  </li>
#     <br> Search Criteria: <br><img src="./img/CompassSearchFields.PNG" width="500"/>
#     <br> Search Results: <br><img src="./img/CompassSearchResults.PNG" width="500"/></li>
#     <br><li><b>(400 Points)Scratching NLTK</b><br>Crawl the following page<br>
#     <a href="https://www.nme.com/features/greta-thunberg-full-speech-to-the-un-2019-climate-change-summit-2550824">Greta Thunberg UN Speech</a></li>
#     <br> Tasks:
#     <br><ul>
#         <li>Get the content of her speech</li>
#         <li>Build a dataset that list all words in this speech and how many times each word appears</li>
#         <li>Sort the list of words by <br>a).Alphabetically. <br> b). by frequency
#         <li>Lemmatize all words</li>
#         <li>Choose ~30 "difficult" words and get the synonyms and antoyms for them.</li>
#     </ul>
#     </li>
# </ol>

# %%
#1. What we are doing is to find the best college for a person based on their info. How we can do this is by using python, react, web crawling, and AI to produce an accurate output.

# %%
#2. Check github for files.

# %%
#3

    
    
def getSResult():
   
    # get search criteria
    search=[]
    a=[]
    b=[]
    soup=BeautifulSoup(open('C:\\Users\\kentt\\stempro\\hw\\midterms\\college1.html'))
    for item in soup.find_all('button'):
        for x in item.find_all("span"):
            query = x.text.strip()
            a = query.split(':')
            search.append(a)
    print("Search\n"+str(search))
    
    
    
    
    # get search result
    collegeName = []
    myFit=[]
    satMath=[]
    satReading=[]
    act=[]
    avgHighSchoolGPA=[]
    for item1 in soup.find_all('table'):
        for y1 in item1.find_all("div", {"class":"show-for-medium-up"}):
            for x1 in y1.find_all("div", {"class":"text-large block-tighter"}):
                query1 = x1.text.strip()
                query1.strip()
                query2 = query1.replace("\n","")
                collegeName.append(query2)
                
                
    for item2 in soup.find_all('table'):
        for y2 in item2.find_all("div", {"class":"show-for-medium-up"}):
            for x2 in y2.find_all("div", {"class":"text-strong display-inline-block"}):
                aquery1 = x2.text.strip()
                aquery1.strip()
                aquery2 = query1.replace("\n","")
                myFit.append(query2)
            print(myFit)
                
    
getSResult()
# Out:
# Search
# [['Location', '  New York'], ['GPA', ' 3.5'], ['SAT Composite', ' 1580'], ['ACT', ' 32'], ['Enrollment', ' 0 - 6,440'], ['Tuition and Fees', ' < $0 - $26,000']]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-28-7cfa13585f17> in <module>
#      46
#      47
# ---> 48 getSResult()
#
# <ipython-input-28-7cfa13585f17> in getSResult()
#      43                 aquery2 = aquery1.replace("\n","")
#      44                 myFit.append(aquery2)
# ---> 45             print(x2)
#      46
#      47
#
# UnboundLocalError: local variable 'x2' referenced before assignment

# %%
#4
def getUrlList(url = "https://www.nme.com/features/greta-thunberg-full-speech-to-the-un-2019-climate-change-summit-2550824"):

    res = requests.get(url)
    html_page = res.content
    soup = BeautifulSoup(html_page, 'lxml')
    text= []
    dis = []
    moreword = []
    synonyms = []
    antonyms = []
    syn = ['urgency','toxic','technologies','sucking','situation','setting','presented','plea','nowhere','odds','matter','leaders','justice','kept','irreversible','impassioned','heartfelt','gigatons','extinction','equity','eternal','crystal','consequences','childhood','betrayal','billions','aspects','additional','activist']

    firstp = soup.p    
    for x in firstp.find_all_next('p'):
        name = x.text.strip()
        if name.startswith("Everyone") or name.startswith("NME") or name.startswith('©'):
            dis.append(name)
        else:
            text.append(name)
    
     
    
    
    
    for i in text:
        i=re.sub(r'[.,()“”!?]','',i).split()
        for word in i:
            word=word.lower()
            moreword.append(word)

    
            
    
    
    
    print("List of words sorted alphabetically")
    pp.pprint(sorted(moreword))
    
    print("List of words sorted by frequency")
    
    counts = Counter(moreword)
    pp.pprint(counts)
    
    
    print('Lemmatizing all words with Porter Stemmer\n')
    print('Word\t\t\t\tStem')
    stem = PorterStemmer()
    for e in moreword:
        lol=int(len(e)/8)
        if lol == 1:
            print(e+'\t\t\t'+stem.stem(e))
        elif lol == 2:
            print(e+'\t\t'+stem.stem(e))
        else:
            print(e+'\t\t\t\t'+stem.stem(e))
            
            
    
    print("List of synonyms and antonyms for 30 words")
    for xd in syn:
        for sqyn in wordnet.synsets(xd):
            for l in sqyn.lemmas():
                synonyms.append(l.name())
                if l.antonyms():
                    antonyms.append(l.antonyms()[0].name())
        pp.pprint('Word: ' + str(xd))
        pp.pprint('Synonyms:' + str(synonyms))
        pp.pprint('Antonyms:' + str(antonyms))
    
getUrlList()
# Out:
# List of words sorted alphabetically
# ['10',
#  '15°c',
#  '15°c',
#  '1st',
#  '2018',
#  '30',
#  '350',
#  '420',
#  '50%',
#  '50%',
#  '50%',
#  '67%',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'about',
#  'acceptable',
#  'acceptable',
#  'act',
#  'additional',
#  'air',
#  'air',
#  'all',
#  'all',
#  'all',
#  'all',
#  'all',
#  'already',
#  'also',
#  'am',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'angry',
#  'any',
#  'are',
#  'are',
#  'are',
#  'are',
#  'are',
#  'are',
#  'are',
#  'are',
#  'are',
#  'are',
#  'are',
#  'as',
#  'aspects',
#  'away',
#  'away',
#  'back',
#  'back',
#  'barely',
#  'be',
#  'be',
#  'be',
#  'be',
#  'be',
#  'be',
#  'be',
#  'be',
#  'because',
#  'because',
#  'been',
#  'beginning',
#  'believe',
#  'believe',
#  'below',
#  'below',
#  'best',
#  'betrayal',
#  'beyond',
#  'billions',
#  'budget',
#  'business',
#  'but',
#  'but',
#  'but',
#  'by',
#  'by',
#  'can',
#  'can',
#  'chain',
#  'chance',
#  'chance',
#  'change',
#  'childhood',
#  'choose',
#  'clear',
#  'climate',
#  'co2',
#  'co2',
#  'co2',
#  'collapsing',
#  'come',
#  'come',
#  'coming',
#  'consequences',
#  'continue',
#  'control',
#  'crystal',
#  'cutting',
#  'dare',
#  'dare',
#  'dare',
#  'dare',
#  'do',
#  'doing',
#  'don’t',
#  'down',
#  'draw',
#  'dreams',
#  'dying',
#  'economic',
#  'ecosystems',
#  'eight-and-a0-half',
#  'emission',
#  'emissions',
#  'emit',
#  'empty',
#  'enough',
#  'enough',
#  'entire',
#  'entirely',
#  'equity',
#  'eternal',
#  'evil',
#  'exist',
#  'extinction',
#  'eyes',
#  'fail',
#  'failing',
#  'failing',
#  'fairy',
#  'feedback',
#  'figure',
#  'figures',
#  'for',
#  'for',
#  'for',
#  'forgive',
#  'future',
#  'generation',
#  'generations',
#  'get',
#  'gigatons',
#  'gigatons',
#  'given',
#  'gives',
#  'global',
#  'gone',
#  'growth',
#  'had',
#  'half',
#  'has',
#  'has',
#  'have',
#  'have',
#  'have',
#  'hear',
#  'here',
#  'here',
#  'here',
#  'here',
#  'hidden',
#  'hope',
#  'how',
#  'how',
#  'how',
#  'how',
#  'how',
#  'human',
#  'hundreds',
#  'i',
#  'i',
#  'i',
#  'i',
#  'i',
#  'i',
#  'idea',
#  'if',
#  'if',
#  'in',
#  'in',
#  'in',
#  'in',
#  'in',
#  'in',
#  'in',
#  'include',
#  'ipcc',
#  'irreversible',
#  'is',
#  'is',
#  'is',
#  'is',
#  'is',
#  'is',
#  'is',
#  'is',
#  'it',
#  'it',
#  'it',
#  'i’m',
#  'january',
#  'justice',
#  'kept',
#  'less',
#  'less',
#  'let',
#  'levels',
#  'like',
#  'like',
#  'line',
#  'line',
#  'live',
#  'look',
#  'loops',
#  'lucky',
#  'mass',
#  'matter',
#  'mature',
#  'may',
#  'message',
#  'money',
#  'more',
#  'most',
#  'my',
#  'my',
#  'my',
#  'my',
#  'needed',
#  'never',
#  'no',
#  'not',
#  'not',
#  'not',
#  'not',
#  'not',
#  'not',
#  'now',
#  'nowhere',
#  'numbers',
#  'numbers',
#  'ocean',
#  'odds',
#  'of',
#  'of',
#  'of',
#  'of',
#  'of',
#  'of',
#  'of',
#  'of',
#  'of',
#  'of',
#  'of',
#  'of',
#  'of',
#  'of',
#  'off',
#  'on',
#  'on',
#  'on',
#  'on',
#  'one',
#  'ones',
#  'only',
#  'or',
#  'or',
#  'other',
#  'our',
#  'out',
#  'people',
#  'people',
#  'people',
#  'people',
#  'plans',
#  'points',
#  'politics',
#  'pollution',
#  'popular',
#  'presented',
#  'pretend',
#  'reactions',
#  'really',
#  'refuse',
#  'rely',
#  'remaining',
#  'right',
#  'right',
#  'rise',
#  'risk',
#  'risks',
#  'sad',
#  'say',
#  'say',
#  'say',
#  'school',
#  'science',
#  'setting',
#  'should',
#  'shouldn’t',
#  'side',
#  'sight',
#  'simply',
#  'situation',
#  'so',
#  'solutions',
#  'solutions',
#  'solutions',
#  'solved',
#  'some',
#  'starting',
#  'staying',
#  'staying',
#  'still',
#  'still',
#  'stolen',
#  'sucking',
#  'suffering',
#  'tales',
#  'talk',
#  'technical',
#  'technologies',
#  'tell',
#  'temperature',
#  'than',
#  'than',
#  'than',
#  'thank',
#  'that',
#  'that',
#  'that',
#  'that',
#  'that',
#  'that',
#  'that',
#  'that',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'then',
#  'there',
#  'these',
#  'these',
#  'they',
#  'this',
#  'this',
#  'this',
#  'those',
#  'tipping',
#  'to',
#  'to',
#  'to',
#  'to',
#  'to',
#  'to',
#  'to',
#  'to',
#  'to',
#  'to',
#  'to',
#  'to',
#  'to',
#  'today',
#  'today',
#  'today’s',
#  'tons',
#  'too',
#  'toxic',
#  'uncomfortable',
#  'understand',
#  'understand',
#  'understood',
#  'up',
#  'up',
#  'upon',
#  'urgency',
#  'us',
#  'us',
#  'us',
#  'us',
#  'us',
#  'us',
#  'usual',
#  'waking',
#  'want',
#  'warming',
#  'watching',
#  'we',
#  'we',
#  'we',
#  'we',
#  'we',
#  'we’ll',
#  'when',
#  'where',
#  'whether',
#  'who',
#  'will',
#  'will',
#  'will',
#  'will',
#  'with',
#  'with',
#  'with',
#  'with',
#  'with',
#  'with',
#  'with',
#  'words',
#  'world',
#  'world',
#  'would',
#  'wrong',
#  'years',
#  'years',
#  'years',
#  'yet',
#  'yet',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'young',
#  'young',
#  'your',
#  'your',
#  'your']
# List of words sorted by frequency
# Counter({'you': 22,
#          'the': 19,
#          'and': 17,
#          'of': 14,
#          'to': 13,
#          'are': 11,
#          'is': 8,
#          'that': 8,
#          'be': 8,
#          'in': 7,
#          'with': 7,
#          'i': 6,
#          'us': 6,
#          'not': 6,
#          'all': 5,
#          'how': 5,
#          'we': 5,
#          'a': 5,
#          'my': 4,
#          'here': 4,
#          'on': 4,
#          'people': 4,
#          'dare': 4,
#          'will': 4,
#          'this': 3,
#          'for': 3,
#          'have': 3,
#          'your': 3,
#          'than': 3,
#          'years': 3,
#          'say': 3,
#          'solutions': 3,
#          'but': 3,
#          '50%': 3,
#          'co2': 3,
#          'it': 3,
#          'up': 2,
#          'back': 2,
#          'yet': 2,
#          'come': 2,
#          'young': 2,
#          'can': 2,
#          'has': 2,
#          'away': 2,
#          'enough': 2,
#          'understand': 2,
#          'believe': 2,
#          'because': 2,
#          'if': 2,
#          'still': 2,
#          'failing': 2,
#          'chance': 2,
#          'staying': 2,
#          'below': 2,
#          '15°c': 2,
#          'acceptable': 2,
#          'numbers': 2,
#          'by': 2,
#          'air': 2,
#          'world': 2,
#          'gigatons': 2,
#          'today': 2,
#          'less': 2,
#          'or': 2,
#          'line': 2,
#          'these': 2,
#          'like': 2,
#          'right': 2,
#          'message': 1,
#          'we’ll': 1,
#          'watching': 1,
#          'wrong': 1,
#          'shouldn’t': 1,
#          'should': 1,
#          'school': 1,
#          'other': 1,
#          'side': 1,
#          'ocean': 1,
#          'hope': 1,
#          'stolen': 1,
#          'dreams': 1,
#          'childhood': 1,
#          'empty': 1,
#          'words': 1,
#          'i’m': 1,
#          'one': 1,
#          'lucky': 1,
#          'ones': 1,
#          'suffering': 1,
#          'dying': 1,
#          'entire': 1,
#          'ecosystems': 1,
#          'collapsing': 1,
#          'beginning': 1,
#          'mass': 1,
#          'extinction': 1,
#          'talk': 1,
#          'about': 1,
#          'money': 1,
#          'fairy': 1,
#          'tales': 1,
#          'eternal': 1,
#          'economic': 1,
#          'growth': 1,
#          'more': 1,
#          '30': 1,
#          'science': 1,
#          'been': 1,
#          'crystal': 1,
#          'clear': 1,
#          'continue': 1,
#          'look': 1,
#          'doing': 1,
#          'when': 1,
#          'politics': 1,
#          'needed': 1,
#          'nowhere': 1,
#          'sight': 1,
#          'hear': 1,
#          'urgency': 1,
#          'no': 1,
#          'matter': 1,
#          'sad': 1,
#          'angry': 1,
#          'am': 1,
#          'don’t': 1,
#          'want': 1,
#          'really': 1,
#          'understood': 1,
#          'situation': 1,
#          'kept': 1,
#          'act': 1,
#          'then': 1,
#          'would': 1,
#          'evil': 1,
#          'refuse': 1,
#          'popular': 1,
#          'idea': 1,
#          'cutting': 1,
#          'our': 1,
#          'emissions': 1,
#          'half': 1,
#          '10': 1,
#          'only': 1,
#          'gives': 1,
#          'risks': 1,
#          'setting': 1,
#          'off': 1,
#          'irreversible': 1,
#          'chain': 1,
#          'reactions': 1,
#          'beyond': 1,
#          'human': 1,
#          'control': 1,
#          'may': 1,
#          'those': 1,
#          'do': 1,
#          'include': 1,
#          'tipping': 1,
#          'points': 1,
#          'most': 1,
#          'feedback': 1,
#          'loops': 1,
#          'additional': 1,
#          'warming': 1,
#          'hidden': 1,
#          'toxic': 1,
#          'pollution': 1,
#          'aspects': 1,
#          'equity': 1,
#          'climate': 1,
#          'justice': 1,
#          'they': 1,
#          'also': 1,
#          'rely': 1,
#          'generation': 1,
#          'sucking': 1,
#          'hundreds': 1,
#          'billions': 1,
#          'tons': 1,
#          'out': 1,
#          'technologies': 1,
#          'barely': 1,
#          'exist': 1,
#          'so': 1,
#          'risk': 1,
#          'simply': 1,
#          'who': 1,
#          'live': 1,
#          'consequences': 1,
#          '67%': 1,
#          'global': 1,
#          'temperature': 1,
#          'rise': 1,
#          'best': 1,
#          'odds': 1,
#          'given': 1,
#          'ipcc': 1,
#          'had': 1,
#          '420': 1,
#          'emit': 1,
#          'january': 1,
#          '1st': 1,
#          '2018': 1,
#          'figure': 1,
#          'already': 1,
#          'down': 1,
#          '350': 1,
#          'pretend': 1,
#          'solved': 1,
#          'business': 1,
#          'as': 1,
#          'usual': 1,
#          'some': 1,
#          'technical': 1,
#          'today’s': 1,
#          'emission': 1,
#          'levels': 1,
#          'remaining': 1,
#          'budget': 1,
#          'entirely': 1,
#          'gone': 1,
#          'eight-and-a0-half': 1,
#          'there': 1,
#          'any': 1,
#          'plans': 1,
#          'presented': 1,
#          'figures': 1,
#          'too': 1,
#          'uncomfortable': 1,
#          'mature': 1,
#          'tell': 1,
#          'starting': 1,
#          'betrayal': 1,
#          'eyes': 1,
#          'future': 1,
#          'generations': 1,
#          'upon': 1,
#          'choose': 1,
#          'fail': 1,
#          'never': 1,
#          'forgive': 1,
#          'let': 1,
#          'get': 1,
#          'now': 1,
#          'where': 1,
#          'draw': 1,
#          'waking': 1,
#          'change': 1,
#          'coming': 1,
#          'whether': 1,
#          'thank': 1})
# Lemmatizing all words with Porter Stemmer
#
# Word				Stem
# my				my
# message				messag
# is				is
# that				that
# we’ll				we’ll
# be				be
# watching			watch
# you				you
# this				thi
# is				is
# all				all
# wrong				wrong
# i				i
# shouldn’t			shouldn’t
# be				be
# up				up
# here				here
# i				i
# should				should
# be				be
# back				back
# in				in
# school				school
# on				on
# the				the
# other				other
# side				side
# of				of
# the				the
# ocean				ocean
# yet				yet
# you				you
# all				all
# come				come
# to				to
# us				us
# young				young
# people				peopl
# for				for
# hope				hope
# how				how
# dare				dare
# you				you
# you				you
# have				have
# stolen				stolen
# my				my
# dreams				dream
# and				and
# my				my
# childhood			childhood
# with				with
# your				your
# empty				empti
# words				word
# yet				yet
# i’m				i’m
# one				one
# of				of
# the				the
# lucky				lucki
# ones				one
# people				peopl
# are				are
# suffering			suffer
# people				peopl
# are				are
# dying				die
# entire				entir
# ecosystems			ecosystem
# are				are
# collapsing			collaps
# we				we
# are				are
# in				in
# the				the
# beginning			begin
# of				of
# a				a
# mass				mass
# extinction			extinct
# and				and
# all				all
# you				you
# can				can
# talk				talk
# about				about
# is				is
# money				money
# and				and
# fairy				fairi
# tales				tale
# of				of
# eternal				etern
# economic			econom
# growth				growth
# how				how
# dare				dare
# you				you
# for				for
# more				more
# than				than
# 30				30
# years				year
# the				the
# science				scienc
# has				ha
# been				been
# crystal				crystal
# clear				clear
# how				how
# dare				dare
# you				you
# continue			continu
# to				to
# look				look
# away				away
# and				and
# come				come
# here				here
# and				and
# say				say
# you				you
# are				are
# doing				do
# enough				enough
# when				when
# the				the
# politics			polit
# and				and
# solutions			solut
# needed				need
# are				are
# nowhere				nowher
# in				in
# sight				sight
# you				you
# say				say
# that				that
# you				you
# hear				hear
# us				us
# and				and
# understand			understand
# the				the
# urgency				urgenc
# but				but
# no				no
# matter				matter
# how				how
# sad				sad
# and				and
# angry				angri
# i				i
# am				am
# i				i
# don’t				don’t
# want				want
# to				to
# believe				believ
# that				that
# because				becaus
# if				if
# you				you
# really				realli
# understood			understood
# the				the
# situation			situat
# and				and
# still				still
# kept				kept
# on				on
# failing				fail
# to				to
# act				act
# then				then
# you				you
# would				would
# be				be
# evil				evil
# and				and
# that				that
# i				i
# refuse				refus
# to				to
# believe				believ
# the				the
# popular				popular
# idea				idea
# of				of
# cutting				cut
# our				our
# emissions			emiss
# in				in
# half				half
# in				in
# 10				10
# years				year
# only				onli
# gives				give
# us				us
# a				a
# 50%				50%
# chance				chanc
# of				of
# staying				stay
# below				below
# 15°c				15°c
# and				and
# risks				risk
# setting				set
# off				off
# irreversible			irrevers
# chain				chain
# reactions			reaction
# beyond				beyond
# human				human
# control				control
# 50%				50%
# may				may
# be				be
# acceptable			accept
# to				to
# you				you
# but				but
# those				those
# numbers				number
# do				do
# not				not
# include				includ
# tipping				tip
# points				point
# most				most
# feedback			feedback
# loops				loop
# additional			addit
# warming				warm
# hidden				hidden
# by				by
# toxic				toxic
# air				air
# pollution			pollut
# and				and
# all				all
# the				the
# aspects				aspect
# of				of
# equity				equiti
# and				and
# climate				climat
# justice				justic
# they				they
# also				also
# rely				reli
# on				on
# my				my
# generation			gener
# sucking				suck
# hundreds			hundr
# of				of
# billions			billion
# of				of
# tons				ton
# of				of
# your				your
# co2				co2
# out				out
# of				of
# the				the
# air				air
# with				with
# technologies			technolog
# that				that
# barely				bare
# exist				exist
# so				so
# a				a
# 50%				50%
# risk				risk
# is				is
# simply				simpli
# not				not
# acceptable			accept
# for				for
# us				us
# we				we
# who				who
# have				have
# to				to
# live				live
# with				with
# the				the
# consequences			consequ
# to				to
# have				have
# a				a
# 67%				67%
# chance				chanc
# of				of
# staying				stay
# below				below
# a				a
# 15°c				15°c
# global				global
# temperature			temperatur
# rise				rise
# the				the
# best				best
# odds				odd
# given				given
# by				by
# the				the
# ipcc				ipcc
# the				the
# world				world
# had				had
# 420				420
# gigatons			gigaton
# of				of
# co2				co2
# to				to
# emit				emit
# back				back
# on				on
# january				januari
# 1st				1st
# 2018				2018
# today				today
# that				that
# figure				figur
# has				ha
# already				alreadi
# down				down
# to				to
# less				less
# than				than
# 350				350
# gigatons			gigaton
# how				how
# dare				dare
# you				you
# pretend				pretend
# that				that
# this				thi
# can				can
# be				be
# solved				solv
# with				with
# business			busi
# as				as
# usual				usual
# and				and
# some				some
# technical			technic
# solutions			solut
# with				with
# today’s				today’
# emission			emiss
# levels				level
# that				that
# remaining			remain
# co2				co2
# budget				budget
# will				will
# be				be
# entirely			entir
# gone				gone
# in				in
# less				less
# than				than
# eight-and-a0-half		eight-and-a0-half
# years				year
# there				there
# will				will
# not				not
# be				be
# any				ani
# solutions			solut
# or				or
# plans				plan
# presented			present
# in				in
# line				line
# with				with
# these				these
# figures				figur
# here				here
# today				today
# because				becaus
# these				these
# numbers				number
# are				are
# too				too
# uncomfortable			uncomfort
# and				and
# you				you
# are				are
# still				still
# not				not
# mature				matur
# enough				enough
# to				to
# tell				tell
# it				it
# like				like
# it				it
# is				is
# you				you
# are				are
# failing				fail
# us				us
# but				but
# the				the
# young				young
# people				peopl
# are				are
# starting			start
# to				to
# understand			understand
# your				your
# betrayal			betray
# the				the
# eyes				eye
# of				of
# all				all
# future				futur
# generations			gener
# are				are
# upon				upon
# you				you
# and				and
# if				if
# you				you
# choose				choos
# to				to
# fail				fail
# us				us
# i				i
# say				say
# we				we
# will				will
# never				never
# forgive				forgiv
# you				you
# we				we
# will				will
# not				not
# let				let
# you				you
# get				get
# away				away
# with				with
# this				thi
# right				right
# here				here
# right				right
# now				now
# is				is
# where				where
# we				we
# draw				draw
# the				the
# line				line
# the				the
# world				world
# is				is
# waking				wake
# up				up
# and				and
# change				chang
# is				is
# coming				come
# whether				whether
# you				you
# like				like
# it				it
# or				or
# not				not
# thank				thank
# you				you
# List of synonyms and antonyms for 30 words
# 'Word: urgency'
# "Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', 'urging']"
# 'Antonyms:[]'
# 'Word: toxic'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic']")
# "Antonyms:['nontoxic']"
# 'Word: technologies'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology']")
# "Antonyms:['nontoxic']"
# 'Word: sucking'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck']")
# "Antonyms:['nontoxic', 'bottlefeed']"
# 'Word: situation'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation']")
# "Antonyms:['nontoxic', 'bottlefeed']"
# 'Word: setting'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure']")
# "Antonyms:['nontoxic', 'bottlefeed', 'rise']"
# 'Word: presented'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present']")
# "Antonyms:['nontoxic', 'bottlefeed', 'rise']"
# 'Word: plea'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea']")
# "Antonyms:['nontoxic', 'bottlefeed', 'rise']"
# 'Word: nowhere'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere']")
# "Antonyms:['nontoxic', 'bottlefeed', 'rise']"
# 'Word: odds'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds']")
# "Antonyms:['nontoxic', 'bottlefeed', 'rise']"
# 'Word: matter'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds', 'matter', 'affair', 'thing', 'topic', "
#  "'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', "
#  "'count', 'matter', 'weigh']")
# "Antonyms:['nontoxic', 'bottlefeed', 'rise']"
# 'Word: leaders'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds', 'matter', 'affair', 'thing', 'topic', "
#  "'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', "
#  "'count', 'matter', 'weigh', 'leadership', 'leaders', 'leader', "
#  "'drawing_card', 'loss_leader', 'leader']")
# "Antonyms:['nontoxic', 'bottlefeed', 'rise', 'follower']"
# 'Word: justice'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds', 'matter', 'affair', 'thing', 'topic', "
#  "'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', "
#  "'count', 'matter', 'weigh', 'leadership', 'leaders', 'leader', "
#  "'drawing_card', 'loss_leader', 'leader', 'justice', 'justness', 'justice', "
#  "'judge', 'justice', 'jurist', 'Department_of_Justice', 'Justice_Department', "
#  "'Justice', 'DoJ']")
# "Antonyms:['nontoxic', 'bottlefeed', 'rise', 'follower', 'injustice']"
# 'Word: kept'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds', 'matter', 'affair', 'thing', 'topic', "
#  "'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', "
#  "'count', 'matter', 'weigh', 'leadership', 'leaders', 'leader', "
#  "'drawing_card', 'loss_leader', 'leader', 'justice', 'justness', 'justice', "
#  "'judge', 'justice', 'jurist', 'Department_of_Justice', 'Justice_Department', "
#  "'Justice', 'DoJ', 'keep', 'maintain', 'hold', 'continue', 'go_on', "
#  "'proceed', 'go_along', 'keep', 'keep', 'hold_on', 'prevent', 'keep', "
#  "'observe', 'keep', 'observe', 'keep', 'maintain', 'keep', 'keep', "
#  "'maintain', 'keep', 'retain', 'continue', 'keep', 'keep_on', 'sustain', "
#  "'keep', 'maintain', 'keep', 'stay_fresh', 'observe', 'celebrate', 'keep', "
#  "'restrain', 'keep', 'keep_back', 'hold_back', 'keep', 'preserve', 'keep', "
#  "'keep_open', 'hold_open', 'keep', 'save', 'keep', 'keep', 'keep', "
#  "'maintain', 'keep', 'preserve', 'keep', 'unbroken', 'kept']")
# ("Antonyms:['nontoxic', 'bottlefeed', 'rise', 'follower', 'injustice', "
#  "'discontinue', 'lose', 'let', 'break', 'broken']")
# 'Word: irreversible'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds', 'matter', 'affair', 'thing', 'topic', "
#  "'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', "
#  "'count', 'matter', 'weigh', 'leadership', 'leaders', 'leader', "
#  "'drawing_card', 'loss_leader', 'leader', 'justice', 'justness', 'justice', "
#  "'judge', 'justice', 'jurist', 'Department_of_Justice', 'Justice_Department', "
#  "'Justice', 'DoJ', 'keep', 'maintain', 'hold', 'continue', 'go_on', "
#  "'proceed', 'go_along', 'keep', 'keep', 'hold_on', 'prevent', 'keep', "
#  "'observe', 'keep', 'observe', 'keep', 'maintain', 'keep', 'keep', "
#  "'maintain', 'keep', 'retain', 'continue', 'keep', 'keep_on', 'sustain', "
#  "'keep', 'maintain', 'keep', 'stay_fresh', 'observe', 'celebrate', 'keep', "
#  "'restrain', 'keep', 'keep_back', 'hold_back', 'keep', 'preserve', 'keep', "
#  "'keep_open', 'hold_open', 'keep', 'save', 'keep', 'keep', 'keep', "
#  "'maintain', 'keep', 'preserve', 'keep', 'unbroken', 'kept', 'irreversible']")
# ("Antonyms:['nontoxic', 'bottlefeed', 'rise', 'follower', 'injustice', "
#  "'discontinue', 'lose', 'let', 'break', 'broken', 'reversible']")
# 'Word: impassioned'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds', 'matter', 'affair', 'thing', 'topic', "
#  "'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', "
#  "'count', 'matter', 'weigh', 'leadership', 'leaders', 'leader', "
#  "'drawing_card', 'loss_leader', 'leader', 'justice', 'justness', 'justice', "
#  "'judge', 'justice', 'jurist', 'Department_of_Justice', 'Justice_Department', "
#  "'Justice', 'DoJ', 'keep', 'maintain', 'hold', 'continue', 'go_on', "
#  "'proceed', 'go_along', 'keep', 'keep', 'hold_on', 'prevent', 'keep', "
#  "'observe', 'keep', 'observe', 'keep', 'maintain', 'keep', 'keep', "
#  "'maintain', 'keep', 'retain', 'continue', 'keep', 'keep_on', 'sustain', "
#  "'keep', 'maintain', 'keep', 'stay_fresh', 'observe', 'celebrate', 'keep', "
#  "'restrain', 'keep', 'keep_back', 'hold_back', 'keep', 'preserve', 'keep', "
#  "'keep_open', 'hold_open', 'keep', 'save', 'keep', 'keep', 'keep', "
#  "'maintain', 'keep', 'preserve', 'keep', 'unbroken', 'kept', 'irreversible', "
#  "'ardent', 'fervent', 'fervid', 'fiery', 'impassioned', 'perfervid', "
#  "'torrid']")
# ("Antonyms:['nontoxic', 'bottlefeed', 'rise', 'follower', 'injustice', "
#  "'discontinue', 'lose', 'let', 'break', 'broken', 'reversible']")
# 'Word: heartfelt'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds', 'matter', 'affair', 'thing', 'topic', "
#  "'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', "
#  "'count', 'matter', 'weigh', 'leadership', 'leaders', 'leader', "
#  "'drawing_card', 'loss_leader', 'leader', 'justice', 'justness', 'justice', "
#  "'judge', 'justice', 'jurist', 'Department_of_Justice', 'Justice_Department', "
#  "'Justice', 'DoJ', 'keep', 'maintain', 'hold', 'continue', 'go_on', "
#  "'proceed', 'go_along', 'keep', 'keep', 'hold_on', 'prevent', 'keep', "
#  "'observe', 'keep', 'observe', 'keep', 'maintain', 'keep', 'keep', "
#  "'maintain', 'keep', 'retain', 'continue', 'keep', 'keep_on', 'sustain', "
#  "'keep', 'maintain', 'keep', 'stay_fresh', 'observe', 'celebrate', 'keep', "
#  "'restrain', 'keep', 'keep_back', 'hold_back', 'keep', 'preserve', 'keep', "
#  "'keep_open', 'hold_open', 'keep', 'save', 'keep', 'keep', 'keep', "
#  "'maintain', 'keep', 'preserve', 'keep', 'unbroken', 'kept', 'irreversible', "
#  "'ardent', 'fervent', 'fervid', 'fiery', 'impassioned', 'perfervid', "
#  "'torrid', 'dear', 'devout', 'earnest', 'heartfelt']")
# ("Antonyms:['nontoxic', 'bottlefeed', 'rise', 'follower', 'injustice', "
#  "'discontinue', 'lose', 'let', 'break', 'broken', 'reversible']")
# 'Word: gigatons'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
# ...
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds', 'matter', 'affair', 'thing', 'topic', "
#  "'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', "
#  "'count', 'matter', 'weigh', 'leadership', 'leaders', 'leader', "
#  "'drawing_card', 'loss_leader', 'leader', 'justice', 'justness', 'justice', "
#  "'judge', 'justice', 'jurist', 'Department_of_Justice', 'Justice_Department', "
#  "'Justice', 'DoJ', 'keep', 'maintain', 'hold', 'continue', 'go_on', "
#  "'proceed', 'go_along', 'keep', 'keep', 'hold_on', 'prevent', 'keep', "
#  "'observe', 'keep', 'observe', 'keep', 'maintain', 'keep', 'keep', "
#  "'maintain', 'keep', 'retain', 'continue', 'keep', 'keep_on', 'sustain', "
#  "'keep', 'maintain', 'keep', 'stay_fresh', 'observe', 'celebrate', 'keep', "
#  "'restrain', 'keep', 'keep_back', 'hold_back', 'keep', 'preserve', 'keep', "
#  "'keep_open', 'hold_open', 'keep', 'save', 'keep', 'keep', 'keep', "
#  "'maintain', 'keep', 'preserve', 'keep', 'unbroken', 'kept', 'irreversible', "
#  "'ardent', 'fervent', 'fervid', 'fiery', 'impassioned', 'perfervid', "
#  "'torrid', 'dear', 'devout', 'earnest', 'heartfelt', 'extinction', "
#  "'extinction', 'defunctness', 'extinction', 'extinction', 'extermination', "
#  "'extinction', 'experimental_extinction', 'extinction', 'extinguishing', "
#  "'quenching', 'equity', 'equity', 'fairness', 'equity', 'ageless', 'aeonian', "
#  "'eonian', 'eternal', 'everlasting', 'perpetual', 'unending', 'unceasing', "
#  "'endless', 'eternal', 'interminable', 'crystal', 'crystal', 'crystal', "
#  "'crystallization', 'quartz_glass', 'quartz', 'vitreous_silica', "
#  "'lechatelierite', 'crystal', 'crystal', 'crystal', 'watch_crystal', "
#  "'watch_glass', 'consequence', 'effect', 'outcome', 'result', 'event', "
#  "'issue', 'upshot', 'consequence', 'aftermath', 'consequence', 'import', "
#  "'moment', 'childhood', 'childhood', 'puerility', 'treachery', 'betrayal', "
#  "'treason', 'perfidy', 'betrayal', 'billion', 'one_million_million', "
#  "'1000000000000', 'million', 'billion', 'trillion', 'zillion', 'jillion', "
#  "'gazillion', 'billion', 'one_thousand_million', '1000000000']")
# ("Antonyms:['nontoxic', 'bottlefeed', 'rise', 'follower', 'injustice', "
#  "'discontinue', 'lose', 'let', 'break', 'broken', 'reversible', 'unfairness', "
#  "'inequity', 'inconsequence']")
# 'Word: aspects'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds', 'matter', 'affair', 'thing', 'topic', "
#  "'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', "
#  "'count', 'matter', 'weigh', 'leadership', 'leaders', 'leader', "
#  "'drawing_card', 'loss_leader', 'leader', 'justice', 'justness', 'justice', "
#  "'judge', 'justice', 'jurist', 'Department_of_Justice', 'Justice_Department', "
#  "'Justice', 'DoJ', 'keep', 'maintain', 'hold', 'continue', 'go_on', "
#  "'proceed', 'go_along', 'keep', 'keep', 'hold_on', 'prevent', 'keep', "
#  "'observe', 'keep', 'observe', 'keep', 'maintain', 'keep', 'keep', "
#  "'maintain', 'keep', 'retain', 'continue', 'keep', 'keep_on', 'sustain', "
#  "'keep', 'maintain', 'keep', 'stay_fresh', 'observe', 'celebrate', 'keep', "
#  "'restrain', 'keep', 'keep_back', 'hold_back', 'keep', 'preserve', 'keep', "
#  "'keep_open', 'hold_open', 'keep', 'save', 'keep', 'keep', 'keep', "
#  "'maintain', 'keep', 'preserve', 'keep', 'unbroken', 'kept', 'irreversible', "
#  "'ardent', 'fervent', 'fervid', 'fiery', 'impassioned', 'perfervid', "
#  "'torrid', 'dear', 'devout', 'earnest', 'heartfelt', 'extinction', "
#  "'extinction', 'defunctness', 'extinction', 'extinction', 'extermination', "
#  "'extinction', 'experimental_extinction', 'extinction', 'extinguishing', "
#  "'quenching', 'equity', 'equity', 'fairness', 'equity', 'ageless', 'aeonian', "
#  "'eonian', 'eternal', 'everlasting', 'perpetual', 'unending', 'unceasing', "
#  "'endless', 'eternal', 'interminable', 'crystal', 'crystal', 'crystal', "
#  "'crystallization', 'quartz_glass', 'quartz', 'vitreous_silica', "
#  "'lechatelierite', 'crystal', 'crystal', 'crystal', 'watch_crystal', "
#  "'watch_glass', 'consequence', 'effect', 'outcome', 'result', 'event', "
#  "'issue', 'upshot', 'consequence', 'aftermath', 'consequence', 'import', "
#  "'moment', 'childhood', 'childhood', 'puerility', 'treachery', 'betrayal', "
#  "'treason', 'perfidy', 'betrayal', 'billion', 'one_million_million', "
#  "'1000000000000', 'million', 'billion', 'trillion', 'zillion', 'jillion', "
#  "'gazillion', 'billion', 'one_thousand_million', '1000000000', 'aspect', "
#  "'facet', 'aspect', 'view', 'aspect', 'prospect', 'scene', 'vista', "
#  "'panorama', 'aspect', 'expression', 'look', 'aspect', 'facial_expression', "
#  "'face']")
# ("Antonyms:['nontoxic', 'bottlefeed', 'rise', 'follower', 'injustice', "
#  "'discontinue', 'lose', 'let', 'break', 'broken', 'reversible', 'unfairness', "
#  "'inequity', 'inconsequence']")
# 'Word: additional'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds', 'matter', 'affair', 'thing', 'topic', "
#  "'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', "
#  "'count', 'matter', 'weigh', 'leadership', 'leaders', 'leader', "
#  "'drawing_card', 'loss_leader', 'leader', 'justice', 'justness', 'justice', "
#  "'judge', 'justice', 'jurist', 'Department_of_Justice', 'Justice_Department', "
#  "'Justice', 'DoJ', 'keep', 'maintain', 'hold', 'continue', 'go_on', "
#  "'proceed', 'go_along', 'keep', 'keep', 'hold_on', 'prevent', 'keep', "
#  "'observe', 'keep', 'observe', 'keep', 'maintain', 'keep', 'keep', "
#  "'maintain', 'keep', 'retain', 'continue', 'keep', 'keep_on', 'sustain', "
#  "'keep', 'maintain', 'keep', 'stay_fresh', 'observe', 'celebrate', 'keep', "
#  "'restrain', 'keep', 'keep_back', 'hold_back', 'keep', 'preserve', 'keep', "
#  "'keep_open', 'hold_open', 'keep', 'save', 'keep', 'keep', 'keep', "
#  "'maintain', 'keep', 'preserve', 'keep', 'unbroken', 'kept', 'irreversible', "
#  "'ardent', 'fervent', 'fervid', 'fiery', 'impassioned', 'perfervid', "
#  "'torrid', 'dear', 'devout', 'earnest', 'heartfelt', 'extinction', "
#  "'extinction', 'defunctness', 'extinction', 'extinction', 'extermination', "
#  "'extinction', 'experimental_extinction', 'extinction', 'extinguishing', "
#  "'quenching', 'equity', 'equity', 'fairness', 'equity', 'ageless', 'aeonian', "
#  "'eonian', 'eternal', 'everlasting', 'perpetual', 'unending', 'unceasing', "
#  "'endless', 'eternal', 'interminable', 'crystal', 'crystal', 'crystal', "
#  "'crystallization', 'quartz_glass', 'quartz', 'vitreous_silica', "
#  "'lechatelierite', 'crystal', 'crystal', 'crystal', 'watch_crystal', "
#  "'watch_glass', 'consequence', 'effect', 'outcome', 'result', 'event', "
#  "'issue', 'upshot', 'consequence', 'aftermath', 'consequence', 'import', "
#  "'moment', 'childhood', 'childhood', 'puerility', 'treachery', 'betrayal', "
#  "'treason', 'perfidy', 'betrayal', 'billion', 'one_million_million', "
#  "'1000000000000', 'million', 'billion', 'trillion', 'zillion', 'jillion', "
#  "'gazillion', 'billion', 'one_thousand_million', '1000000000', 'aspect', "
#  "'facet', 'aspect', 'view', 'aspect', 'prospect', 'scene', 'vista', "
#  "'panorama', 'aspect', 'expression', 'look', 'aspect', 'facial_expression', "
#  "'face', 'extra', 'additional']")
# ("Antonyms:['nontoxic', 'bottlefeed', 'rise', 'follower', 'injustice', "
#  "'discontinue', 'lose', 'let', 'break', 'broken', 'reversible', 'unfairness', "
#  "'inequity', 'inconsequence']")
# 'Word: activist'
# ("Synonyms:['urgency', 'urgency', 'urgency', 'importunity', 'urgency', "
#  "'urging', 'toxic', 'technology', 'engineering', 'engineering', "
#  "'engineering_science', 'applied_science', 'technology', 'sucking', 'suck', "
#  "'suction', 'suck', 'suck', 'suck', 'suck_in', 'suck', 'fellate', 'suck', "
#  "'blow', 'go_down_on', 'absorb', 'suck', 'imbibe', 'soak_up', 'sop_up', "
#  "'suck_up', 'draw', 'take_in', 'take_up', 'breastfeed', 'suckle', 'suck', "
#  "'nurse', 'wet-nurse', 'lactate', 'give_suck', 'situation', "
#  "'state_of_affairs', 'situation', 'position', 'situation', 'site', "
#  "'situation', 'position', 'post', 'berth', 'office', 'spot', 'billet', "
#  "'place', 'situation', 'setting', 'scene', 'setting', 'background', 'scope', "
#  "'mise_en_scene', 'stage_setting', 'setting', 'context', 'circumstance', "
#  "'setting', 'setting', 'place_setting', 'setting', 'mount', 'setting', 'put', "
#  "'set', 'place', 'pose', 'position', 'lay', 'determine', 'set', 'specify', "
#  "'set', 'determine', 'define', 'fix', 'limit', 'set', 'mark', 'set', 'set', "
#  "'fix', 'prepare', 'set_up', 'ready', 'gear_up', 'set', 'set', 'set', "
#  "'localize', 'localise', 'place', 'set', 'go_down', 'go_under', 'arrange', "
#  "'set', 'plant', 'set', 'set', 'jell', 'set', 'congeal', 'typeset', 'set', "
#  "'set', 'set', 'countersink', 'set', 'sic', 'set', 'place', 'put', 'set', "
#  "'rig', 'set', 'set_up', 'set_up', 'lay_out', 'set', 'adjust', 'set', "
#  "'correct', 'fructify', 'set', 'dress', 'arrange', 'set', 'do', 'coif', "
#  "'coiffe', 'coiffure', 'show', 'demo', 'exhibit', 'present', 'demonstrate', "
#  "'present', 'represent', 'lay_out', 'stage', 'present', 'represent', "
#  "'present', 'submit', 'present', 'pose', 'award', 'present', 'give', 'gift', "
#  "'present', 'deliver', 'present', 'introduce', 'present', 'acquaint', "
#  "'portray', 'present', 'confront', 'face', 'present', 'present', 'salute', "
#  "'present', 'supplication', 'plea', 'plea', 'plea', 'nowhere', 'nowhere', "
#  "'odds', 'odds', 'betting_odds', 'matter', 'affair', 'thing', 'topic', "
#  "'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', "
#  "'count', 'matter', 'weigh', 'leadership', 'leaders', 'leader', "
#  "'drawing_card', 'loss_leader', 'leader', 'justice', 'justness', 'justice', "
#  "'judge', 'justice', 'jurist', 'Department_of_Justice', 'Justice_Department', "
#  "'Justice', 'DoJ', 'keep', 'maintain', 'hold', 'continue', 'go_on', "
#  "'proceed', 'go_along', 'keep', 'keep', 'hold_on', 'prevent', 'keep', "
#  "'observe', 'keep', 'observe', 'keep', 'maintain', 'keep', 'keep', "
#  "'maintain', 'keep', 'retain', 'continue', 'keep', 'keep_on', 'sustain', "
#  "'keep', 'maintain', 'keep', 'stay_fresh', 'observe', 'celebrate', 'keep', "
#  "'restrain', 'keep', 'keep_back', 'hold_back', 'keep', 'preserve', 'keep', "
#  "'keep_open', 'hold_open', 'keep', 'save', 'keep', 'keep', 'keep', "
#  "'maintain', 'keep', 'preserve', 'keep', 'unbroken', 'kept', 'irreversible', "
#  "'ardent', 'fervent', 'fervid', 'fiery', 'impassioned', 'perfervid', "
#  "'torrid', 'dear', 'devout', 'earnest', 'heartfelt', 'extinction', "
#  "'extinction', 'defunctness', 'extinction', 'extinction', 'extermination', "
#  "'extinction', 'experimental_extinction', 'extinction', 'extinguishing', "
#  "'quenching', 'equity', 'equity', 'fairness', 'equity', 'ageless', 'aeonian', "
#  "'eonian', 'eternal', 'everlasting', 'perpetual', 'unending', 'unceasing', "
#  "'endless', 'eternal', 'interminable', 'crystal', 'crystal', 'crystal', "
#  "'crystallization', 'quartz_glass', 'quartz', 'vitreous_silica', "
#  "'lechatelierite', 'crystal', 'crystal', 'crystal', 'watch_crystal', "
#  "'watch_glass', 'consequence', 'effect', 'outcome', 'result', 'event', "
#  "'issue', 'upshot', 'consequence', 'aftermath', 'consequence', 'import', "
#  "'moment', 'childhood', 'childhood', 'puerility', 'treachery', 'betrayal', "
#  "'treason', 'perfidy', 'betrayal', 'billion', 'one_million_million', "
#  "'1000000000000', 'million', 'billion', 'trillion', 'zillion', 'jillion', "
#  "'gazillion', 'billion', 'one_thousand_million', '1000000000', 'aspect', "
#  "'facet', 'aspect', 'view', 'aspect', 'prospect', 'scene', 'vista', "
#  "'panorama', 'aspect', 'expression', 'look', 'aspect', 'facial_expression', "
#  "'face', 'extra', 'additional', 'militant', 'activist', 'activist', "
#  "'activistic']")
# ("Antonyms:['nontoxic', 'bottlefeed', 'rise', 'follower', 'injustice', "
#  "'discontinue', 'lose', 'let', 'break', 'broken', 'reversible', 'unfairness', "
#  "'inequity', 'inconsequence']")

# %%
display(Markdown(
"""
# Python Exam (For Python students):
<ol>
<li>(100 points)Write a program that contains a while loop that repeatedly asks the user to enter numeric miles they run each week.  Append each run to a list called “distance”. You may use this format [(“week1”, 23.1), (“week2”, 12.2)…]  
</li><br><li>(100 points)Write a program that get the max, min, average, number of runs etc. 
</li><br><li>(100 points)Write a program that prompts the user to enter in an unlimited number of colors. Test to make sure that the user did not already enter a color before storing it (i.e. “We’re sorry, but you’ve already added the color ‘yellow’”). When the user types the string “exit” you should stop collecting colors. The print out the colors entered in alphabetical order.  
</li><br><li>(100 points)Write a function that generates a random letter from the string ‘BINGO’. Here is a sample running of this program: x = generate_bingo_letter() print (x) 
</li><br><li>(100 points)Define a function fraction(fstring), where the argument passed in stores a fraction as a string. The function should return a floating point number that is the value of the fraction. 
 
Examples of using the function: <br>
         print(fraction(“3/4”))  # prints  .750 <br>
         print(fraction(“1/3”))  # prints   0.333 <br>
     
 
</li><br><li>(Bonus. 300 Points) Write a function balance_parens(astring) that inputs a string with parenthesized sub-­‐strings, which may be nested (e.g., could be a Python arithmetic expression). The function returns True if all of the parentheses that are opened are properly closed, otherwise it returns False. 
<br>
For example, the following string is balanced: 
<br>
“ A * ( (B + C) – (D – E) )” 
<br>
And the following string is not balanced: 
<br> 
“  A ((B * C)  + (D      
</li>
</ol>

"""
))

# %%
display(Markdown(
"""
## You may use the following libraries for the exams. 
import re <br>
import spacy  <br>
from spacy import displacy <br>
import en_core_web_sm <br>
from pathlib import Path <br>
from IPython.display import display, Markdown, Latex  <br>
import sys <br>
import csv <br>
import pandas as pd <br>
import numpy as np <br>
import os <br>
from os import path <br>
from datetime import datetime <br>
from urllib.parse import urlparse, urljoin <br>
import requests <br>
import ntpath <br>
from bs4 import BeautifulSoup, Comment <br>
import time <br>
from pprint import pprint  <br>
import shutil <br>
import tldextract <br>
import multiprocessing <br>
from multiprocessing import Process, Queue, cpu_count <br>
import os <br>
from os import path, listdir  <br>
"""
))

# %%
#1
def run(weeks=10):
    distance = []
    week = 1
    while week <= weeks:
        try:
            miles = input('How many miles have you run in week' + str(week) + '\n')
            milesint = float(miles)
            pair = ('week' + str(week), milesint)
            week += 1
            distance.append(pair)
        except ValueError:
            print("Please enter a number")
            continue

            
    return(distance)
run()

# %%
#2
y=0
data= [('week1', 23.0),
 ('week2', 4334.0),
 ('week3', 324.0),
 ('week4', 4.0),
 ('week5', 35321.0),
 ('week6', 562134.0),
 ('week7', 43214.0),
 ('week8', 5.0),
 ('week9', 2354.0),
 ('week10', 5.0)]

number_of_runs = len(data)

max_miles=max(data, key=lambda x: x[1])
min_miles=min(data, key=lambda x: x[1])
avg=sum(x[1] for x in data)/number_of_runs

print("The farthest distance you've run is " + str(max_miles[1]) + ' miles ' + 'on ' + str(max_miles[0]))
print("The shortest distance you've run is " + str(min_miles[1]) + ' miles ' + 'on ' + str(min_miles[0]))
print("Your average distance ran is " + str(avg) + " miles for " + str(number_of_runs))
print("You've gone on " + str(number_of_runs) + " runs so far.")

# %%
#3
def listcolors():
    colors = []
    while True:
        usercolor = input("Add a color: ")
        if usercolor == "exit":
            break
            
        if usercolor in colors:
            print("We’re sorry, but you’ve already added the color " + usercolor)
            continue
        else:
            colors.append(usercolor)
        
    print(sorted(colors))
            
listcolors()

# %%
#4
def generate_bingo_letter():
    bingo="BINGO"
    
    rand = random.randint(0,4)        
    return bingo[rand]
    
    #return random.choice(bingo)


x = generate_bingo_letter()
print(x)

# %%
#5
def fraction(fstring):
    sum = 0
    splitfract=fstring.split()
    if len(splitfract) != 1 and len(splitfract) != 2:
        print("invalid fraction")
        sys.exit()
        
       
    for x in splitfract:
        try:
            a = Fraction(x)
            rounded = round(float(a),3)
            sum = sum + rounded
        except ValueError as e :
            print(e)
    return(sum)


fraction('74398231 3841234/1324132')

# %%
#6
def balance_parens(astring):
    thestack = []
    index = 0
    
    
    while index < len(astring):
        lpar = astring[index]
        if lpar == "(":
            thestack.append(lpar)
        elif lpar == ')':
            if len(thestack) == 0:
                return False
            else:
                thestack.pop()
        index = index + 1
        
        
    if len(thestack) == 0:
        return True
    else:
        return False


balance_parens("(((((kdkdksadjiajsd))))")
